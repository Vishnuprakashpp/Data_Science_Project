# %%
import pandas as pd
df = pd.read_table("http://bit.ly/chiporders")
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### adding column name and seperating each column

# %%
col_names = ['Id','Age','Gender','Occupation','Revenue']
df = pd.read_table("http://bit.ly/movieusers",sep="|",header=None,names=col_names)
df
# Out:
#       Id  Age Gender     Occupation Revenue
# 0      1   24      M     technician   85711
# 1      2   53      F          other   94043
# 2      3   23      M         writer   32067
# 3      4   24      M     technician   43537
# 4      5   33      F          other   15213
# ..   ...  ...    ...            ...     ...
# 938  939   26      F        student   33319
# 939  940   32      M  administrator   02215
# 940  941   20      M        student   97229
# 941  942   48      F      librarian   78209
# 942  943   22      M        student   77841
#
# [943 rows x 5 columns]

# %%
df.Occupation
df['new_col']=df.Gender + df.Occupation
df.head()
# Out:
#    Id  Age Gender  Occupation Revenue      new_col
# 0   1   24      M  technician   85711  Mtechnician
# 1   2   53      F       other   94043       Fother
# 2   3   23      M      writer   32067      Mwriter
# 3   4   24      M  technician   43537  Mtechnician
# 4   5   33      F       other   15213       Fother

# %% [markdown]
# ### IMDB rating

# %%
df = pd.read_table("http://bit.ly/imdbratings",sep=',')
#df = df.rename(columns= {'star_rating':'StarRating'}) its a tidyious method
#new_col = ['StarRating','Title','Content_Rating','Genre','Duration','ActorsList']
#df.columns=new_col
df.columns = df.columns.str.replace('_','')
df.head()
# Out:
#    starrating                     title contentrating   genre  duration  \
# 0         9.3  The Shawshank Redemption             R   Crime       142
# 1         9.2             The Godfather             R   Crime       175
# 2         9.1    The Godfather: Part II             R   Crime       200
# 3         9.0           The Dark Knight         PG-13  Action       152
# 4         8.9              Pulp Fiction             R   Crime       154
#
#                                           actorslist
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df.drop(['starrating'],axis=1)
df['duration'].sort_values(ascending=False)
df.sort_values('duration',ascending=False)
df.sort_values(['genre','duration'])
# Out:
#      starrating                           title contentrating    genre  \
# 533         7.8                    Run Lola Run             R   Action
# 633         7.7                    The Warriors             R   Action
# 455         7.9                           Taken         PG-13   Action
# 685         7.7                     First Blood             R   Action
# 744         7.6     Mad Max 2: The Road Warrior             R   Action
# ..          ...                             ...           ...      ...
# 421         7.9          The Outlaw Josey Wales            PG  Western
# 263         8.1                       Rio Bravo     NOT RATED  Western
# 6           8.9  The Good, the Bad and the Ugly     NOT RATED  Western
# 59          8.5                Django Unchained             R  Western
# 26          8.6    Once Upon a Time in the West         PG-13  Western
#
#      duration                                         actorslist
# ...

# %% [markdown]
# #### extracting data of duration greater than 175

# %%
boolean = []
for i in df.duration:
    if i>175:
        boolean.append(True)
    else:
        boolean.append(False)
df[boolean]
# Out:
#      starrating                                              title  \
# 2           9.1                             The Godfather: Part II
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 14          8.8              The Lord of the Rings: The Two Towers
# 17          8.7                                      Seven Samurai
# 40          8.5                                     The Green Mile
# 78          8.4                        Once Upon a Time in America
# 82          8.4                                         Braveheart
# 85          8.4                                 Lawrence of Arabia
# 89          8.4                                             Swades
# 93          8.4                        Dilwale Dulhania Le Jayenge
# 109         8.3                                     Dil Chahta Hai
# ...

# %%
#easy way to filter
df[df.duration>175].genre
# Out:
# 2          Crime
# 7      Adventure
# 8      Biography
# 10     Adventure
# 14     Adventure
# 17         Drama
# 40         Crime
# 78         Crime
# 82        Action
# 85     Adventure
# 89         Drama
# 93        Comedy
# 109       Comedy
# 132        Drama
# 142    Adventure
# 143    Biography
# 156    Biography
# 157        Drama
# 166        Drama
# 184        Drama
# 204    Adventure
# 220    Biography
# 245    Adventure
# 300        Crime
# 316        Drama
# 318        Drama
# 335        Drama
# 339    Adventure
# 361        Drama
# 385       Action
# 424    Adventure
# 445    Adventure
# 456        Drama
# 476        Drama
# 534       Action
# 611       Comedy
# 620        Drama
# 630    Biography
# 671       Action
# 767       Action
# Name: genre, dtype: object

# %%
df[(df.contentrating=='R') & (df.genre=='Crime')]
# Out:
#      starrating                     title contentrating  genre  duration  \
# 0           9.3  The Shawshank Redemption             R  Crime       142
# 1           9.2             The Godfather             R  Crime       175
# 2           9.1    The Godfather: Part II             R  Crime       200
# 4           8.9              Pulp Fiction             R  Crime       154
# 21          8.7               City of God             R  Crime       130
# ..          ...                       ...           ...    ...       ...
# 927         7.5                     Brick             R  Crime       110
# 931         7.4              Mean Streets             R  Crime       112
# 950         7.4                     Bound             R  Crime       108
# 969         7.4       Law Abiding Citizen             R  Crime       109
# 978         7.4               Wall Street             R  Crime       126
#
#                                             actorslist
# ...

# %%
df.genre.isin(['Crime'])
